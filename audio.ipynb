# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.64.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (2.9 kB)
# Requirement already satisfied: numpy>=1.22.3 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from librosa) (2.3.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from librosa) (1.16.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from librosa) (1.7.1)
# Requirement already satisfied: joblib>=1.0 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from librosa) (5.2.1)
# Collecting soundfile>=0.12.1 (from librosa)
#   Downloading soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-1.0.0-cp312-abi3-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from librosa) (4.15.0)
# Collecting lazy_loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting standard-aifc (from librosa)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting standard-sunau (from librosa)
#   Downloading standard_sunau-3.13.0-py3-none-any.whl.metadata (914 bytes)
# Requirement already satisfied: packaging in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Collecting llvmlite<0.47,>=0.46.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.46.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (5.0 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from pooch>=1.1->librosa) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.8.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /opt/miniconda3/envs/ds6001/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Collecting standard-chunk (from standard-aifc->librosa)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Collecting audioop-lts (from standard-aifc->librosa)
#   Downloading audioop_lts-0.2.2-cp313-abi3-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading audioread-3.1.0-py3-none-any.whl (23 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading msgpack-1.1.2-cp313-cp313-macosx_11_0_arm64.whl (84 kB)
# Downloading numba-0.64.0-cp313-cp313-macosx_12_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 20.7 MB/s  0:00:00
# Downloading llvmlite-0.46.0-cp313-cp313-macosx_12_0_arm64.whl (37.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 21.5 MB/s  0:00:01 eta 0:00:01
# Downloading pooch-1.9.0-py3-none-any.whl (67 kB)
# Downloading soundfile-0.13.1-py2.py3-none-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.8 MB/s  0:00:00
# Downloading soxr-1.0.0-cp312-abi3-macosx_11_0_arm64.whl (163 kB)
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-macosx_11_0_arm64.whl (26 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Downloading standard_sunau-3.13.0-py3-none-any.whl (7.4 kB)
# Installing collected packages: standard-chunk, soxr, msgpack, llvmlite, lazy_loader, audioop-lts, standard-sunau, standard-aifc, soundfile, pooch, numba, audioread, librosa
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [librosa]2/13 [librosa]]
# Successfully installed audioop-lts-0.2.2 audioread-3.1.0 lazy_loader-0.5 librosa-0.11.0 llvmlite-0.46.0 msgpack-1.1.2 numba-0.64.0 pooch-1.9.0 soundfile-0.13.1 soxr-1.0.0 standard-aifc-3.13.0 standard-chunk-3.13.0 standard-sunau-3.13.0

# %%
import os
import librosa

DATASET_PATH = "Data/genres_original"

X, y = [], []

for genre in os.listdir(DATASET_PATH):
    genre_path = os.path.join(DATASET_PATH, genre)

    if not os.path.isdir(genre_path):
        continue

    for file in os.listdir(genre_path):
        if file.endswith(".wav"):
            file_path = os.path.join(genre_path, file)

            try:
                audio, sr = librosa.load(file_path, sr=None)
                X.append(audio)
                y.append(genre)
            except Exception as e:
                print("Skipping:", file_path)

print("Loaded", len(X), "files")
# Out:
# /var/folders/wr/66f4zf893q541yt3pc0dq3_00000gn/T/ipykernel_17548/3580705052.py:19: UserWarning: PySoundFile failed. Trying audioread instead.
#   audio, sr = librosa.load(file_path, sr=None)
# Skipping: Data/genres_original/jazz/jazz.00054.wav
# Loaded 999 files
